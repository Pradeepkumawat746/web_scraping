# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url='https://www.scrapethissite.com/pages/simple/'

# %%
country=[]
capital=[]
population=[]
area=[]

# %%
try:
    response=requests.get(url)
    response.raise_for_status()
except Exception as e:
    print(e)
else:
    response=requests.get(url)
    soup=BeautifulSoup(response.content,"html.parser")
    n=soup.find_all('h3')
    for i in n:
        con=i.get_text()
        country.append(con)
    
        capi=soup.find_all('div',class_='country-info')
    for i in capi:
        capitals=i.find('span',class_='country-capital').get_text(strip=True)
        populations=i.find('span',class_='country-population').get_text(strip=True)
        Areas =i.find('span',class_='country-area').get_text(strip=True)
        capital.append(capitals)
        population.append(populations)
        area.append(Areas)

clean=[item.replace('\n','').replace(',','')for item in country]
data={'country':clean,
      'capital':capital,
      'population':population,
      'Area':area
    }
data1=pd.DataFrame(data)

# %%
data1
# Out:
#                                                country           capital  \
# 0                                Andorra           ...  Andorra la Vella
# 1                                United Arab Emirat...         Abu Dhabi
# 2                                Afghanistan       ...             Kabul
# 3                                Antigua and Barbud...        St. John's
# 4                                Anguilla          ...        The Valley
# ..                                                 ...               ...
# 745                              Yemen             ...             Sanaa
# 746                              Mayotte           ...         Mamoudzou
# 747                              South Africa      ...          Pretoria
# 748                              Zambia            ...            Lusaka
# 749                              Zimbabwe          ...            Harare
#
#     population       Area
# 0        84000      468.0
# 1      4975593    82880.0
# ...
